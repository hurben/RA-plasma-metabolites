# %%
input_file <- '/Users/m221138/RA_project/analysis/monotonic_change_r1/class4_r1/MLR.hd4.ready.monotonic_profile_0.1.tsv'
# input_file <- '/Users/m221138/RA_project/analysis/monotonic_change_r1/class4_r1/MLR.clp.sc.monotonic_profile_0.1.tsv'
input_df <- read.csv(input_file,sep="\t", header=TRUE)

# %%
input_df
# Out:
#    chemID    r_mean   l_mean   m_mean    h_mean    monotonic_status pval
# 1  100000257 1.007273 1.253624 1.3559561 1.6003000 up               0.0022
# 2  100004208 1.520807 1.325594 1.0571854 0.8691545 down             0.0109
# 3  100020536 2.113737 1.717076 1.4883220 1.0294909 down             0.0112
# 4  100001605 1.359525 1.224159 1.0153098 0.8703545 down             0.0063
# 5  100001121 1.870229 3.185571 4.7602122 6.4022636 up               0.0132
# 6  100015831 1.229253 1.107447 0.9524610 0.8820182 down             0.0017
# 7  100001950 1.265141 1.165171 0.9591634 0.7766273 down             0.0012
# 8  100006098 1.716600 1.555112 1.1330415 0.9067636 down             0.0108
# 9  100002761 1.355227 1.530765 1.7521707 2.0105909 up               0.0123
# 10 100009246 1.607703 1.251676 1.1105902 0.7667273 down             0.0311
# 11 100001510 1.474705 1.240206 1.1184122 0.8619273 down             0.0083
#    endpoint_log2fc
# 1  0.6678878
# 2  0.8071522
# 3  1.0378650
# ...

# %%
pvalue_list <- as.numeric(as.matrix(input_df$pval))

# %%
input_df$padj <- p.adjust(pvalue_list, method="bonferroni")

# %%
input_df
# Out:
#    chemID    r_mean   l_mean   m_mean    h_mean    monotonic_status pval
# 1  100000257 1.007273 1.253624 1.3559561 1.6003000 up               0.0022
# 2  100004208 1.520807 1.325594 1.0571854 0.8691545 down             0.0109
# 3  100020536 2.113737 1.717076 1.4883220 1.0294909 down             0.0112
# 4  100001605 1.359525 1.224159 1.0153098 0.8703545 down             0.0063
# 5  100001121 1.870229 3.185571 4.7602122 6.4022636 up               0.0132
# 6  100015831 1.229253 1.107447 0.9524610 0.8820182 down             0.0017
# 7  100001950 1.265141 1.165171 0.9591634 0.7766273 down             0.0012
# 8  100006098 1.716600 1.555112 1.1330415 0.9067636 down             0.0108
# 9  100002761 1.355227 1.530765 1.7521707 2.0105909 up               0.0123
# 10 100009246 1.607703 1.251676 1.1105902 0.7667273 down             0.0311
# 11 100001510 1.474705 1.240206 1.1184122 0.8619273 down             0.0083
#    endpoint_log2fc padj
# 1  0.6678878       0.0242
# ...

# %%
input_df
# Out:
#    chemID    r_mean   l_mean   m_mean    h_mean    monotonic_status pval
# 1  100000257 1.007273 1.253624 1.3559561 1.6003000 up               0.0022
# 2  100004208 1.520807 1.325594 1.0571854 0.8691545 down             0.0109
# 3  100020536 2.113737 1.717076 1.4883220 1.0294909 down             0.0112
# 4  100001605 1.359525 1.224159 1.0153098 0.8703545 down             0.0063
# 5  100001121 1.870229 3.185571 4.7602122 6.4022636 up               0.0132
# 6  100015831 1.229253 1.107447 0.9524610 0.8820182 down             0.0017
# 7  100001950 1.265141 1.165171 0.9591634 0.7766273 down             0.0012
# 8  100006098 1.716600 1.555112 1.1330415 0.9067636 down             0.0108
# 9  100002761 1.355227 1.530765 1.7521707 2.0105909 up               0.0123
# 10 100009246 1.607703 1.251676 1.1105902 0.7667273 down             0.0311
# 11 100001510 1.474705 1.240206 1.1184122 0.8619273 down             0.0083
#    endpoint_log2fc padj
# 1  0.6678878       0.008066667
# ...

# %%
output_file = '/Users/m221138/RA_project/analysis/monotonic_change_r1/class4_r1/MLR.hd4.ready.monotonic_profile_0.1.padj.tsv'
# output_file = '/Users/m221138/RA_project/analysis/monotonic_change_r1/class4_r1/MLR.clp.sc.monotonic_profile_0.1.padj.tsv'
write.table(input_df, file=output_file, sep="\t", quote=FALSE, row.names=FALSE)
